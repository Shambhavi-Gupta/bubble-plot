# %% [markdown]
# <a href="https://colab.research.google.com/github/Shambhavi-Gupta/bubble-plot/blob/master/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this plot you can get the knowledge of four different things i.e. in which state what is the population,gender ratio and urban population. For better view the mouse on the bubbles and get the knowledge of all the four things.

# %%
fig= px.scatter(data_frame = df, x='Urban population', y='Gender Ratio', size ='Population' , 
                 color = 'State / Union Territory', hover_name='State / Union Territory',log_x=1, size_max=100)
fig.update_layout(title=' Bubble Chart ')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9c070f92-00ad-4593-ae33-cb5cd921af00" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c070f92-00ad-4593-ae33-cb5cd921af00")) {
#                     Plotly.newPlot(
#                         '9c070f92-00ad-4593-ae33-cb5cd921af00',
# ...
